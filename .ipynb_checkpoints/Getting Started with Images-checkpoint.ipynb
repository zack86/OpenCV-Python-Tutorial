# %% [markdown]
# ## Read Image

# %%
# !pip install opencv-python

# %%
import numpy as np
import cv2
import os

# %%
os.sys.path
# Out:
# ['',
#  'c:\\python35\\python35.zip',
#  'c:\\python35\\DLLs',
#  'c:\\python35\\lib',
#  'c:\\python35',
#  'c:\\python35\\lib\\site-packages',
#  'c:\\python35\\lib\\site-packages\\flask-0.12.2-py3.5.egg',
#  'c:\\python35\\lib\\site-packages\\click-6.7-py3.5.egg',
#  'c:\\python35\\lib\\site-packages\\itsdangerous-0.24-py3.5.egg',
#  'c:\\python35\\lib\\site-packages\\werkzeug-0.12.2-py3.5.egg',
#  'c:\\python35\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Zack\\.ipython']

# %%
print("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 3.4.0

# %%
# Load an color image in grayscale
img = cv2.imread('messi5.jpg',0)
img
# Out:
# array([[181, 247, 251, ..., 203, 177, 170],
#        [217, 255, 250, ..., 211, 178, 167],
#        [247, 255, 245, ..., 218, 180, 164],
#        ...,
#        [ 13,  13,  12, ...,   0,  16,   0],
#        [ 11,  10,  10, ...,   0,   0,   0],
#        [ 17,  17,  16, ...,   0,   4,   0]], dtype=uint8)

# %%
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2 = cv2.imread('Koala.jpg', 1) # 1 is default meaning color
img2
# Out:
# array([[ 90,  92,  96, ...,  93, 100,  88],
#        [ 89,  95,  93, ...,  93,  97,  86],
#        [ 95,  94,  95, ...,  93,  96,  92],
#        ...,
#        [211, 213, 210, ..., 125, 118, 123],
#        [206, 200, 195, ..., 129, 123, 125],
#        [203, 195, 189, ..., 123, 118, 124]], dtype=uint8)

# %%
cv2.namedWindow('koala', cv2.WINDOW_NORMAL) # Allow window re-size
cv2.imshow('koala', img2)
cv2.waitKey(0)
cv2.destroyWindow('koala')

# %% [markdown]
# ## Write Image

# %%
cv2.imwrite('messigray.png', img)
# Out:
# True

# %% [markdown]
# ## Sum it up

# %%
import numpy as np
import cv2
img = cv2.imread('messi5.jpg',0)
cv2.imshow('image',img)
k = cv2.waitKey(0)
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv2.imwrite('messi5gray.png',img)
    cv2.destroyAllWindows()

# %% [markdown]
# ## Using Matplotlib

# %%
from matplotlib import pyplot as plt

img = cv2.imread('messi5.jpg',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# ## OpenCV (BGR) vs Matplotlib (RGB)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('messi4.jpg')
b,g,r = cv2.split(img)
img2 = cv2.merge([r,g,b]) # conversion
plt.subplot(121);plt.imshow(img) # expects distorted color
plt.subplot(122);plt.imshow(img2) # expect true color
plt.show()

cv2.imshow('bgr image',img) # expects true color
cv2.imshow('rgb image',img2) # expects distorted color
cv2.waitKey(0)
cv2.destroyAllWindows()
